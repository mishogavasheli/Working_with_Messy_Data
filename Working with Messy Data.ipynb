# %% [markdown]
# ## Import libraries and select the directory

# %% [markdown]
# ## Assemble the tools

# %%
import numpy as np 
import pandas as pd 
import time
from datetime import date
import matplotlib.pyplot as plt 
import seaborn as sns
import warnings
# %matplotlib inline
warnings.filterwarnings("ignore")

# %%
from sklearn import linear_model 
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

# %% [markdown]
# ---

# %% [markdown]
# ## Running the files  into  df

# %%
df=pd.read_csv('alldata.csv')

# %% [markdown]
# ###  Show info

# %%
df.head()
# Out:
#                                             position             company  \
# 0                               Development Director             ALS TDI
# 1  An Ostentatiously-Excitable Principal Research...  The Hexagon Lavish
# 2                                     Data Scientist      Xpert Staffing
# 3                                       Data Analyst      Operation HOPE
# 4  Assistant Professor -TT - Signal Processing & ...    Emory University
#
#                                          description  reviews  \
# 0  Development Director\nALS Therapy Development ...      NaN
# 1  Job Description\n\n"The road that leads to acc...      NaN
# 2  Growing company located in the Atlanta, GA are...      NaN
# 3  DEPARTMENT: Program OperationsPOSITION LOCATIO...     44.0
# 4  DESCRIPTION\nThe Emory University Department o...    550.0
#
#              location
# 0  Atlanta, GA 30301
# 1         Atlanta, GA
# 2         Atlanta, GA
# 3  Atlanta, GA 30303
# 4         Atlanta, GA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6964 entries, 0 to 6963
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   position     6953 non-null   object
#  1   company      6953 non-null   object
#  2   description  6953 non-null   object
#  3   reviews      5326 non-null   float64
#  4   location     6953 non-null   object
# dtypes: float64(1), object(4)
# memory usage: 272.2+ KB

# %%
df.shape
# Out:
# (6964, 5)

# %% [markdown]
# ## EDA and data cleaning

# %% [markdown]
# ### - check the distribution of num var
# ### - remove nulls

# %%
df['reviews'].isna()
# Out:
# 0        True
# 1        True
# 2        True
# 3       False
# 4       False
#         ...
# 6959    False
# 6960    False
# 6961    False
# 6962    False
# 6963    False
# Name: reviews, Length: 6964, dtype: bool

# %%
df=df.dropna()

# %%
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# ### Value counts from position

# %%
df['position'].value_counts(ascending=False)
# Out:
# Data Scientist                                        204
# Senior Data Scientist                                  53
# Research Analyst                                       44
# Data Engineer                                          39
# Machine Learning Engineer                              26
#                                                      ...
# BI - Analytics - Cloud Platform Operations Analyst      1
# LINCS Postdoc Fellow                                    1
# Sr. SDTM Programmer                                     1
# Administrative Coordinator                              1
# Software Engineer/Data Scientist, NLP                   1
# Name: position, Length: 4221, dtype: int64

# %%
df['company'].value_counts(ascending=False)
# Out:
# Amazon.com              357
# Ball Aerospace          187
# Microsoft               137
# Google                  134
# NYU Langone Health       76
#                        ...
# Ameriprise Financial      1
# Siluria Technologies      1
# Tendril                   1
# Aviva                     1
# The Hershey Company       1
# Name: company, Length: 1302, dtype: int64

# %% [markdown]
# ### Standardize header names and lower case the whole text

# %%
df.head()
# Out:
#                                             position             company  \
# 0                                       Data Analyst      Operation HOPE
# 1  Assistant Professor -TT - Signal Processing & ...    Emory University
# 2                        Manager of Data Engineering  McKinsey & Company
# 3       Product Specialist - Periscope, New Ventures  McKinsey & Company
# 4  Junior to Mid-level Engineer, Geologist or Env...                Wood
#
#                                          description  reviews  \
# 0  DEPARTMENT: Program OperationsPOSITION LOCATIO...     44.0
# 1  DESCRIPTION\nThe Emory University Department o...    550.0
# 2  Qualifications\nBachelor’s degree in Computer ...    385.0
# 3  Qualifications\nBachelor’s degree\n5-7 years o...    385.0
# 4  Overview / Responsibilities\nWood Environment ...    899.0
#
#              location
# 0  Atlanta, GA 30303
# 1         Atlanta, GA
# 2  Atlanta, GA 30318
# 3  Atlanta, GA 30318
# 4         Atlanta, GA

# %%
df.columns.to_list()
# Out:
# ['position', 'company', 'description', 'reviews', 'location']

# %%
def standardize_col(col):
    return col.lower().replace(" ","_")

# %%
new_cols=[]
for col in df.columns:
    new_cols.append(standardize_col(col))
new_cols
# Out:
# ['position', 'company', 'description', 'reviews', 'location']

# %%
standardize_col("position")
# Out:
# 'position'

# %%
df.columns=new_cols
df.columns
# Out:
# Index(['position', 'company', 'description', 'reviews', 'location'], dtype='object')

# %%
df = pd.concat([df[columns].astype(str).str.lower() 
           for columns in df.columns], axis=1)

# %%
df["position"].str.lower()
# Out:
# 0                                            data analyst
# 1       assistant professor -tt - signal processing & ...
# 2                             manager of data engineering
# 3            product specialist - periscope, new ventures
# 4       junior to mid-level engineer, geologist or env...
#                               ...
# 5321            data developer / machine learning analyst
# 5322                                          scientist i
# 5323                                     intern scientist
# 5324                      senior data & applied scientist
# 5325              principal data scientist, deep learning
# Name: position, Length: 5326, dtype: object

# %%
df
# Out:
#                                                position  \
# 0                                          data analyst
# 1     assistant professor -tt - signal processing & ...
# 2                           manager of data engineering
# 3          product specialist - periscope, new ventures
# 4     junior to mid-level engineer, geologist or env...
# ...                                                 ...
# 5321          data developer / machine learning analyst
# 5322                                        scientist i
# 5323                                   intern scientist
# 5324                    senior data & applied scientist
# 5325            principal data scientist, deep learning
#
#                                company  \
# 0                       operation hope
# 1                     emory university
# 2                   mckinsey & company
# 3                   mckinsey & company
# 4                                 wood
# ...                                ...
# 5321                            netapp
# 5322  pharmacyclics, an abbvie company
# 5323                          oath inc
# 5324                         microsoft
# 5325                           comcast
#
#                                             description  reviews  \
# 0     department: program operationsposition locatio...     44.0
# 1     description\nthe emory university department o...    550.0
# 2     qualifications\nbachelor’s degree in computer ...    385.0
# 3     qualifications\nbachelor’s degree\n5-7 years o...    385.0
# 4     overview / responsibilities\nwood environment ...    899.0
# ...                                                 ...      ...
# 5321  are you data-driven? we at netapp believe in t...    574.0
# 5322  pharmacyclics is committed to the development ...     26.0
# 5323  oath, a subsidiary of verizon, is a values-led...      5.0
# 5324  we are the bing core relevance team responsibl...   4618.0
# 5325  comcast’s technology &amp; product organizatio...  11610.0
#
#                  location
# 0      atlanta, ga 30303
# 1             atlanta, ga
# 2      atlanta, ga 30318
# 3      atlanta, ga 30318
# 4             atlanta, ga
# ...                   ...
# 5321        sunnyvale, ca
# 5322        sunnyvale, ca
# 5323        sunnyvale, ca
# 5324        sunnyvale, ca
# 5325  sunnyvale, ca 94089
#
# [5326 rows x 5 columns]

# %% [markdown]
# ## Create a new column based on if-else condition

# %% [markdown]
# - scien = Data Scienctist → 0
# - analy  = Data Analyst → 1
# - data eng = Data Engineer → 2
# - machin = Machine learning engineer → 3
# - archi = Data architect → 4

# %%
df.loc[df['position'].str.contains("data sci"),'roles'] = 'data_scientist'
df.loc[df['position'].str.contains("data analy"),'roles'] = 'data_analyst'
df.loc[df['position'].str.contains("data eng"),'roles'] = 'data_engineer'
df.loc[df['position'].str.contains("machine learn"),'roles'] = 'machine_learning_engineer'
df.loc[df['position'].str.contains("data arch"),'roles'] = 'data_architect'

# %%
df
# Out:
#                                                position  \
# 0                                          data analyst
# 1     assistant professor -tt - signal processing & ...
# 2                           manager of data engineering
# 3          product specialist - periscope, new ventures
# 4     junior to mid-level engineer, geologist or env...
# ...                                                 ...
# 5321          data developer / machine learning analyst
# 5322                                        scientist i
# 5323                                   intern scientist
# 5324                    senior data & applied scientist
# 5325            principal data scientist, deep learning
#
#                                company  \
# 0                       operation hope
# 1                     emory university
# 2                   mckinsey & company
# 3                   mckinsey & company
# 4                                 wood
# ...                                ...
# 5321                            netapp
# 5322  pharmacyclics, an abbvie company
# 5323                          oath inc
# 5324                         microsoft
# 5325                           comcast
#
#                                             description  reviews  \
# 0     department: program operationsposition locatio...     44.0
# 1     description\nthe emory university department o...    550.0
# 2     qualifications\nbachelor’s degree in computer ...    385.0
# 3     qualifications\nbachelor’s degree\n5-7 years o...    385.0
# 4     overview / responsibilities\nwood environment ...    899.0
# ...                                                 ...      ...
# 5321  are you data-driven? we at netapp believe in t...    574.0
# 5322  pharmacyclics is committed to the development ...     26.0
# 5323  oath, a subsidiary of verizon, is a values-led...      5.0
# 5324  we are the bing core relevance team responsibl...   4618.0
# 5325  comcast’s technology &amp; product organizatio...  11610.0
#
#                  location                      roles
# 0      atlanta, ga 30303                data_analyst
# 1             atlanta, ga  machine_learning_engineer
# 2      atlanta, ga 30318               data_engineer
# 3      atlanta, ga 30318                         NaN
# 4             atlanta, ga                        NaN
# ...                   ...                        ...
# 5321        sunnyvale, ca  machine_learning_engineer
# 5322        sunnyvale, ca                        NaN
# 5323        sunnyvale, ca                        NaN
# 5324        sunnyvale, ca                        NaN
# 5325  sunnyvale, ca 94089             data_scientist
#
# [5326 rows x 6 columns]

# %%
df = pd.concat([df[columns].astype(str).str.lower() 
           for columns in df.columns], axis=1)

# %%
df["roles"] = df["roles"].replace("nan","different_field")

# %%
df
# Out:
#                                                position  \
# 0                                          data analyst
# 1     assistant professor -tt - signal processing & ...
# 2                           manager of data engineering
# 3          product specialist - periscope, new ventures
# 4     junior to mid-level engineer, geologist or env...
# ...                                                 ...
# 5321          data developer / machine learning analyst
# 5322                                        scientist i
# 5323                                   intern scientist
# 5324                    senior data & applied scientist
# 5325            principal data scientist, deep learning
#
#                                company  \
# 0                       operation hope
# 1                     emory university
# 2                   mckinsey & company
# 3                   mckinsey & company
# 4                                 wood
# ...                                ...
# 5321                            netapp
# 5322  pharmacyclics, an abbvie company
# 5323                          oath inc
# 5324                         microsoft
# 5325                           comcast
#
#                                             description  reviews  \
# 0     department: program operationsposition locatio...     44.0
# 1     description\nthe emory university department o...    550.0
# 2     qualifications\nbachelor’s degree in computer ...    385.0
# 3     qualifications\nbachelor’s degree\n5-7 years o...    385.0
# 4     overview / responsibilities\nwood environment ...    899.0
# ...                                                 ...      ...
# 5321  are you data-driven? we at netapp believe in t...    574.0
# 5322  pharmacyclics is committed to the development ...     26.0
# 5323  oath, a subsidiary of verizon, is a values-led...      5.0
# 5324  we are the bing core relevance team responsibl...   4618.0
# 5325  comcast’s technology &amp; product organizatio...  11610.0
#
#                  location                      roles
# 0      atlanta, ga 30303                data_analyst
# 1             atlanta, ga  machine_learning_engineer
# 2      atlanta, ga 30318               data_engineer
# 3      atlanta, ga 30318             different_field
# 4             atlanta, ga            different_field
# ...                   ...                        ...
# 5321        sunnyvale, ca  machine_learning_engineer
# 5322        sunnyvale, ca            different_field
# 5323        sunnyvale, ca            different_field
# 5324        sunnyvale, ca            different_field
# 5325  sunnyvale, ca 94089             data_scientist
#
# [5326 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5326 entries, 0 to 5325
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   position     5326 non-null   object
#  1   company      5326 non-null   object
#  2   description  5326 non-null   object
#  3   reviews      5326 non-null   object
#  4   location     5326 non-null   object
#  5   roles        5326 non-null   object
# dtypes: object(6)
# memory usage: 249.8+ KB

# %% [markdown]
# ## Create different Var for DATA ANALYSTS SKILLS

# %%
#create a new df
df_skills = df

# %%
df_skills
# Out:
#                                                position  \
# 0                                          data analyst
# 1     assistant professor -tt - signal processing & ...
# 2                           manager of data engineering
# 3          product specialist - periscope, new ventures
# 4     junior to mid-level engineer, geologist or env...
# ...                                                 ...
# 5321          data developer / machine learning analyst
# 5322                                        scientist i
# 5323                                   intern scientist
# 5324                    senior data & applied scientist
# 5325            principal data scientist, deep learning
#
#                                company  \
# 0                       operation hope
# 1                     emory university
# 2                   mckinsey & company
# 3                   mckinsey & company
# 4                                 wood
# ...                                ...
# 5321                            netapp
# 5322  pharmacyclics, an abbvie company
# 5323                          oath inc
# 5324                         microsoft
# 5325                           comcast
#
#                                             description  reviews  \
# 0     department: program operationsposition locatio...     44.0
# 1     description\nthe emory university department o...    550.0
# 2     qualifications\nbachelor’s degree in computer ...    385.0
# 3     qualifications\nbachelor’s degree\n5-7 years o...    385.0
# 4     overview / responsibilities\nwood environment ...    899.0
# ...                                                 ...      ...
# 5321  are you data-driven? we at netapp believe in t...    574.0
# 5322  pharmacyclics is committed to the development ...     26.0
# 5323  oath, a subsidiary of verizon, is a values-led...      5.0
# 5324  we are the bing core relevance team responsibl...   4618.0
# 5325  comcast’s technology &amp; product organizatio...  11610.0
#
#                  location                      roles
# 0      atlanta, ga 30303                data_analyst
# 1             atlanta, ga  machine_learning_engineer
# 2      atlanta, ga 30318               data_engineer
# 3      atlanta, ga 30318             different_field
# 4             atlanta, ga            different_field
# ...                   ...                        ...
# 5321        sunnyvale, ca  machine_learning_engineer
# 5322        sunnyvale, ca            different_field
# 5323        sunnyvale, ca            different_field
# 5324        sunnyvale, ca            different_field
# 5325  sunnyvale, ca 94089             data_scientist
#
# [5326 rows x 6 columns]

# %% [markdown]
# ### Add programming languages and skils columns

# %%
df_skills["python"] = df_skills["description"].str.contains("python")
df_skills["r"] = df_skills["description"].str.contains("r")
df_skills["sas"] = df_skills["description"].str.contains("sas")
df_skills["oracle"] = df_skills["description"].str.contains("oracle")
df_skills["java"] = df_skills["description"].str.contains("java")

# %%
df_skills["sql"] = df_skills["description"].str.contains("sql")
df_skills["dataviz"] = df_skills["description"].str.contains("data visualization")
df_skills["statistics"] = df_skills["description"].str.contains("statistics")
df_skills["excel"] = df_skills["description"].str.contains("excel")
df_skills["business_intelligence"] = df_skills["description"].str.contains("business intelligence")
df_skills["communication"] = df_skills["description"].str.contains("communication")
df_skills["machine_learning"] = df_skills["description"].str.contains("machine learning")
df_skills["teamwork"] = df_skills["description"].str.contains("teamwork")

# %%
df_skills
# Out:
#                                                position  \
# 0                                          data analyst
# 1     assistant professor -tt - signal processing & ...
# 2                           manager of data engineering
# 3          product specialist - periscope, new ventures
# 4     junior to mid-level engineer, geologist or env...
# ...                                                 ...
# 5321          data developer / machine learning analyst
# 5322                                        scientist i
# 5323                                   intern scientist
# 5324                    senior data & applied scientist
# 5325            principal data scientist, deep learning
#
#                                company  \
# 0                       operation hope
# 1                     emory university
# 2                   mckinsey & company
# 3                   mckinsey & company
# 4                                 wood
# ...                                ...
# 5321                            netapp
# 5322  pharmacyclics, an abbvie company
# 5323                          oath inc
# 5324                         microsoft
# 5325                           comcast
#
#                                             description  reviews  \
# 0     department: program operationsposition locatio...     44.0
# 1     description\nthe emory university department o...    550.0
# 2     qualifications\nbachelor’s degree in computer ...    385.0
# 3     qualifications\nbachelor’s degree\n5-7 years o...    385.0
# 4     overview / responsibilities\nwood environment ...    899.0
# ...                                                 ...      ...
# 5321  are you data-driven? we at netapp believe in t...    574.0
# 5322  pharmacyclics is committed to the development ...     26.0
# 5323  oath, a subsidiary of verizon, is a values-led...      5.0
# 5324  we are the bing core relevance team responsibl...   4618.0
# 5325  comcast’s technology &amp; product organizatio...  11610.0
#
#                  location                      roles  python     r    sas  \
# 0      atlanta, ga 30303                data_analyst    True  True   True
# 1             atlanta, ga  machine_learning_engineer   False  True  False
# 2      atlanta, ga 30318               data_engineer   False  True  False
# 3      atlanta, ga 30318             different_field   False  True  False
# 4             atlanta, ga            different_field   False  True  False
# ...                   ...                        ...     ...   ...    ...
# 5321        sunnyvale, ca  machine_learning_engineer    True  True  False
# 5322        sunnyvale, ca            different_field   False  True  False
# 5323        sunnyvale, ca            different_field    True  True  False
# 5324        sunnyvale, ca            different_field   False  True  False
# 5325  sunnyvale, ca 94089             data_scientist    True  True  False
#
#       oracle   java    sql  dataviz  statistics  excel  business_intelligence  \
# 0      False  False   True     True       False  False                  False
# 1      False  False  False    False       False  False                  False
# 2      False  False   True    False       False  False                  False
# 3      False  False  False    False       False   True                   True
# 4      False  False  False    False       False   True                  False
# ...      ...    ...    ...      ...         ...    ...                    ...
# 5321    True   True   True    False       False   True                   True
# 5322   False  False  False    False       False   True                  False
# 5323    True   True   True    False        True  False                  False
# 5324   False   True  False    False       False  False                  False
# 5325   False   True   True    False        True   True                   True
#
#       communication  machine_learning  teamwork
# 0             False             False     False
# 1             False              True     False
# 2             False             False     False
# 3              True             False     False
# 4              True             False     False
# ...             ...               ...       ...
# 5321           True              True      True
# 5322           True             False     False
# 5323          False              True     False
# 5324           True              True     False
# 5325           True              True     False
#
# [5326 rows x 19 columns]

# %% [markdown]
# ### creat plot for programming languages

# %%
df_skills['roles'].value_counts().plot(kind='bar',title='roles')
# Out:
# <AxesSubplot:title={'center':'roles'}>

# %%
df_export = df_skills.drop(['description'], axis=1)

# %%
df_export.to_csv('df_export.csv',index=False)

# %% [markdown]
# ## Filter data and store it in new vars

# %%
da_filtered = df[df['roles'].eq('data_analyst')]
da_filtered
# Out:
#                                               position  \
# 0                                         data analyst
# 26                           scientist - data analysis
# 39              flight safety data analysis fall co-op
# 61                           data analyst supply chain
# 212                       sr data analyst supply chain
# ...                                                ...
# 5068                                  big data analyst
# 5069                             research data analyst
# 5094                           healthcare data analyst
# 5115                          data analyst, s&p - jump
# 5178  lead data analyst - digital test and measurement
#
#                       company  \
# 0              operation hope
# 26    american cancer society
# 39            delta air lines
# 61             the home depot
# 212            the home depot
# ...                       ...
# 5068                 autodesk
# 5069                      jll
# 5094                    medal
# 5115                     uber
# 5178                   target
#
#                                             description  reviews  \
# 0     department: program operationsposition locatio...     44.0
# 26    position description:\nsave lives. fulfill you...    959.0
# 39    responsibilities include duties to support fli...   2963.0
# 61    position purpose:\na data analyst supply chain...  38844.0
# 212   position purpose:\na sr data analyst supply ch...  38844.0
# ...                                                 ...      ...
# 5068  big data analyst\n\n18wd28972\namericas-united...    315.0
# 5069  at jll we are always looking for great talent ...   1786.0
# 5094  welcome to medal! we’re making it easy to shar...      4.0
# 5115  about uber\n\nwe’re changing the way people th...    496.0
# 5178  description:\njoin us as a lead data analyst –...  33275.0
#
#                      location         roles  python     r    sas  oracle  \
# 0          atlanta, ga 30303   data_analyst    True  True   True   False
# 26                atlanta, ga  data_analyst   False  True   True   False
# 39                atlanta, ga  data_analyst    True  True  False   False
# 61                atlanta, ga  data_analyst   False  True  False    True
# 212               atlanta, ga  data_analyst    True  True   True    True
# ...                       ...           ...     ...   ...    ...     ...
# 5068        san francisco, ca  data_analyst   False  True  False   False
# 5069        san francisco, ca  data_analyst   False  True  False   False
# 5094        san francisco, ca  data_analyst   False  True  False   False
# 5115  san francisco, ca 94103  data_analyst    True  True  False   False
# 5178            sunnyvale, ca  data_analyst    True  True  False   False
#
#        java    sql  dataviz  statistics  excel  business_intelligence  \
# 0     False   True     True       False  False                  False
# 26    False  False    False       False  False                  False
# 39    False   True    False        True  False                  False
# 61    False   True    False        True  False                  False
# 212    True   True    False        True   True                  False
# ...     ...    ...      ...         ...    ...                    ...
# 5068  False   True    False       False   True                  False
# 5069  False  False     True       False   True                   True
# 5094  False   True    False       False   True                  False
# 5115  False   True    False       False  False                  False
# 5178   True   True    False        True   True                  False
#
#       communication  machine_learning  teamwork
# 0             False             False     False
# 26             True             False      True
# 39             True              True     False
# 61             True              True     False
# 212            True              True     False
# ...             ...               ...       ...
# 5068          False             False     False
# 5069           True             False     False
# 5094          False             False     False
# 5115          False             False     False
# 5178           True              True     False
#
# [144 rows x 19 columns]

# %%
ds_filtered = df[df['roles'].eq('data_scientist')]
ds_filtered
# Out:
#                                                position  \
# 6     senior associate - cognitive data scientist na...
# 9                      senior associate, data scientist
# 11    business intelligence data science analyst - s...
# 12                                       data scientist
# 17                                       data scientist
# ...                                                 ...
# 5312  systems software performance data scientist su...
# 5314                          lead data scientist - nlp
# 5319                      lead data scientist - haskell
# 5320                   senior data scientist (gec11902)
# 5325            principal data scientist, deep learning
#
#                     company  \
# 6                      kpmg
# 9                      kpmg
# 11            newell brands
# 12                 cotiviti
# 17    norfolk southern corp
# ...                     ...
# 5312                alibaba
# 5314                 target
# 5319                 target
# 5320                walmart
# 5325                comcast
#
#                                             description   reviews  \
# 6     known for being a great place to work and buil...    4494.0
# 9     innovate. collaborate. shine. lighthouse — kpm...    4494.0
# 11    data science analyst– business intelligence\nl...     912.0
# 12    cotiviti is looking for an industry leading da...     104.0
# 17    join a growing data science and advanced analy...     722.0
# ...                                                 ...       ...
# 5312  we are the system performance team of alibaba ...      15.0
# 5314  description:\n\nabout this opportunity\njoin t...   33275.0
# 5319  description:\ntarget is looking for engineers ...   33275.0
# 5320  position description\nproficient in java or py...  148114.0
# 5325  comcast’s technology &amp; product organizatio...   11610.0
#
#                  location           roles  python     r    sas  oracle   java  \
# 6       atlanta, ga 30338  data_scientist   False  True  False   False  False
# 9       atlanta, ga 30338  data_scientist   False  True  False   False  False
# 11            atlanta, ga  data_scientist    True  True  False   False  False
# 12            atlanta, ga  data_scientist    True  True   True   False  False
# 17     atlanta, ga 30309   data_scientist    True  True  False   False  False
# ...                   ...             ...     ...   ...    ...     ...    ...
# 5312        sunnyvale, ca  data_scientist    True  True  False   False  False
# 5314        sunnyvale, ca  data_scientist   False  True  False   False  False
# 5319        sunnyvale, ca  data_scientist   False  True  False   False  False
# 5320  sunnyvale, ca 94086  data_scientist    True  True  False   False   True
# 5325  sunnyvale, ca 94089  data_scientist    True  True  False   False   True
#
#         sql  dataviz  statistics  excel  business_intelligence  communication  \
# 6     False    False        True   True                  False           True
# 9     False     True        True   True                  False          False
# 11     True     True        True  False                   True           True
# 12     True    False        True  False                  False          False
# 17     True    False        True   True                  False           True
# ...     ...      ...         ...    ...                    ...            ...
# 5312   True    False        True   True                  False           True
# 5314  False    False        True   True                  False           True
# 5319  False    False        True  False                  False          False
# 5320  False    False        True  False                  False          False
# 5325   True    False        True   True                   True           True
#
#       machine_learning  teamwork
# 6                 True     False
# 9                 True     False
# 11               False     False
# 12                True     False
# 17                True     False
# ...                ...       ...
# 5312              True     False
# 5314              True     False
# 5319              True     False
# 5320              True     False
# 5325              True     False
#
# [982 rows x 19 columns]

# %%
de_filtered = df[df['roles'].eq('data_engineer')]
de_filtered
# Out:
#                                        position             company  \
# 2                   manager of data engineering  mckinsey & company
# 49                                data engineer              gallup
# 65    data engineer - gc insights, new ventures  mckinsey & company
# 73                         data engineer, scala  captech consulting
# 86      enterprise data analyst & data engineer             novelis
# ...                                         ...                 ...
# 5157                        staff data engineer   walmart ecommerce
# 5164                    principal data engineer              target
# 5170                         lead data engineer              target
# 5214      lead data engineer - devops sunnyvale              target
# 5317                              data engineer          amazon.com
#
#                                             description  reviews  \
# 2     qualifications\nbachelor’s degree in computer ...    385.0
# 49    help gallup fulfill our mission of providing a...    140.0
# 65    qualifications\nstrong academic qualifications...    385.0
# 73    job description\n\nthe data engineer role fall...     14.0
# 86    role overview\n\nnovelis is embarking on the j...    189.0
# ...                                                 ...      ...
# 5157  position description\nwe are part of search en...    141.0
# 5164  description:\njoin the data science &amp; engi...  33275.0
# 5170  description:\ndata science and engineering tea...  33275.0
# 5214  description:\njoin us as a lead data engineer ...  33275.0
# 5317  job description\ntoday, people spend too much ...  25907.0
#
#                 location          roles  python     r    sas  oracle   java  \
# 2     atlanta, ga 30318   data_engineer   False  True  False   False  False
# 49           atlanta, ga  data_engineer    True  True  False   False   True
# 65    atlanta, ga 30318   data_engineer   False  True  False    True  False
# 73           atlanta, ga  data_engineer    True  True  False    True   True
# 86           atlanta, ga  data_engineer    True  True   True   False  False
# ...                  ...            ...     ...   ...    ...     ...    ...
# 5157       sunnyvale, ca  data_engineer    True  True  False   False   True
# 5164       sunnyvale, ca  data_engineer   False  True  False   False  False
# 5170       sunnyvale, ca  data_engineer    True  True  False   False   True
# 5214       sunnyvale, ca  data_engineer    True  True  False   False  False
# 5317       sunnyvale, ca  data_engineer    True  True  False    True  False
#
#         sql  dataviz  statistics  excel  business_intelligence  communication  \
# 2      True    False       False  False                  False          False
# 49    False    False        True  False                  False          False
# 65     True    False       False  False                   True           True
# 73     True    False        True  False                   True          False
# 86    False    False       False  False                  False          False
# ...     ...      ...         ...    ...                    ...            ...
# 5157   True    False       False  False                  False           True
# 5164  False    False       False  False                  False          False
# 5170  False    False       False  False                  False          False
# 5214   True    False       False  False                  False          False
# 5317   True     True       False   True                   True           True
#
#       machine_learning  teamwork
# 2                False     False
# 49                True     False
# 65               False     False
# 73               False     False
# 86                True     False
# ...                ...       ...
# 5157             False     False
# 5164             False     False
# 5170             False     False
# 5214             False     False
# 5317             False     False
#
# [130 rows x 19 columns]

# %%
ml_filtered = df[df['roles'].eq('machine_learning_engineer')]
ml_filtered
# Out:
#                                                position           company  \
# 1     assistant professor -tt - signal processing & ...  emory university
# 51    machine learning / artificial intelligence res...          symantec
# 66    technical evangelist – database, analytics, an...        amazon.com
# 116            tech fall 2018 intern - machine learning            turner
# 117   r&d innovation engineer - video analytics/mach...         honeywell
# ...                                                 ...               ...
# 5308      machine learning specialist, trust and safety            google
# 5310                 applied machine learning scientist        amazon.com
# 5315           machine learning scientist, amazon alexa        amazon.com
# 5318                          manager, machine learning        amazon.com
# 5321          data developer / machine learning analyst            netapp
#
#                                             description  reviews  \
# 1     description\nthe emory university department o...    550.0
# 51    (this is an individual contributor role)\n\nco...    950.0
# 66    job description\ndo you love data? do you like...  25907.0
# 116   the turner story\n\nturner is a division of ti...    375.0
# 117   join a team recognized for leadership, innovat...   6121.0
# ...                                                 ...      ...
# 5308  google's brand is only as strong as our users'...   2474.0
# 5310  job description\nexternal job description\nama...  25907.0
# 5315  job description\namazon is looking for a passi...  25907.0
# 5318  job description\nalexa is amazon's new cloud-b...  25907.0
# 5321  are you data-driven? we at netapp believe in t...    574.0
#
#                 location                      roles  python     r    sas  \
# 1            atlanta, ga  machine_learning_engineer   False  True  False
# 51     atlanta, ga 30338  machine_learning_engineer    True  True  False
# 66           atlanta, ga  machine_learning_engineer   False  True  False
# 116    atlanta, ga 30319  machine_learning_engineer    True  True  False
# 117   atlanta, ga 30308   machine_learning_engineer    True  True  False
# ...                  ...                        ...     ...   ...    ...
# 5308       sunnyvale, ca  machine_learning_engineer   False  True  False
# 5310       sunnyvale, ca  machine_learning_engineer    True  True   True
# 5315       sunnyvale, ca  machine_learning_engineer    True  True  False
# 5318       sunnyvale, ca  machine_learning_engineer   False  True  False
# 5321       sunnyvale, ca  machine_learning_engineer    True  True  False
#
#       oracle   java    sql  dataviz  statistics  excel  business_intelligence  \
# 1      False  False  False    False       False  False                  False
# 51     False  False  False    False       False  False                  False
# 66     False  False  False    False       False   True                  False
# 116    False  False  False    False        True  False                  False
# 117    False   True  False    False       False  False                  False
# ...      ...    ...    ...      ...         ...    ...                    ...
# 5308   False  False  False    False       False  False                  False
# 5310   False  False   True    False        True  False                  False
# 5315   False   True  False    False       False  False                  False
# 5318   False  False  False    False       False   True                  False
# 5321    True   True   True    False       False   True                   True
#
#       communication  machine_learning  teamwork
# 1             False              True     False
# 51             True              True     False
# 66             True              True     False
# 116           False              True     False
# 117            True              True     False
# ...             ...               ...       ...
# 5308           True              True     False
# 5310           True              True     False
# 5315           True              True     False
# 5318           True              True     False
# 5321           True              True      True
#
# [389 rows x 19 columns]

# %%
darch_filtered = df[df['roles'].eq('data_architect')]
darch_filtered
# Out:
#                                                position  \
# 972   manager data architects and database systems g...
# 2563                data architect technical lead, ames
# 2924               head of enterprise data architecture
# 2941                                     data architect
# 3121                                     data architect
# 3426                              senior data architect
# 4604                              senior data architect
# 5022                                     data architect
# 5204  chief data architect (disrupting a multi-billi...
#
#                                                 company  \
# 972                                          massmutual
# 2563                          the aerospace corporation
# 2924                         marsh & mclennan companies
# 2941  businesses united technologies corp. headquarters
# 3121                                        movable ink
# 3426                                          microsoft
# 4604                                             taulia
# 5022                                          metromile
# 5204                                 jobspring partners
#
#                                             description reviews  \
# 972   since 1851, massmutual’s commitment has always...   786.0
# 2563  requisition id: 41481\nall locations: houston,...    82.0
# 2924  location: flexible; new york city preferred\n\...   537.0
# 2941  united technologies corporation (utc) has a de...   831.0
# 3121  movable ink powers meaningful experiences in e...     4.0
# 3426  are you passionate about delivering the best u...  4618.0
# 4604  about taulia:\ntaulia delivers working capital...     3.0
# 5022  about us\n\nmetromile is a start-up that is di...     7.0
# 5204  an autonomous subsidiary of one of the world’s...    27.0
#
#                      location           roles  python     r    sas  oracle  \
# 972          boston, ma 02298  data_architect    True  True  False   False
# 2563  mountain view, ca 94035  data_architect   False  True  False   False
# 2924             new york, ny  data_architect   False  True  False   False
# 2941             new york, ny  data_architect    True  True  False   False
# 3121             new york, ny  data_architect   False  True  False   False
# 3426        redmond, wa 98052  data_architect    True  True  False   False
# 4604  san francisco, ca 94104  data_architect    True  True  False   False
# 5022        san francisco, ca  data_architect    True  True  False   False
# 5204            sunnyvale, ca  data_architect    True  True  False   False
#
#        java    sql  dataviz  statistics  excel  business_intelligence  \
# 972   False   True    False       False  False                  False
# 2563  False   True    False       False  False                  False
# 2924  False  False    False       False  False                  False
# 2941  False  False    False        True   True                  False
# 3121  False  False    False       False  False                  False
# 3426   True   True    False        True   True                  False
# 4604   True  False    False       False   True                  False
# 5022   True  False    False       False  False                  False
# 5204  False  False    False       False   True                  False
#
#       communication  machine_learning  teamwork
# 972            True              True     False
# 2563           True             False     False
# 2924          False             False     False
# 2941           True              True     False
# 3121          False             False     False
# 3426           True              True     False
# 4604           True              True     False
# 5022          False             False     False
# 5204           True              True     False
